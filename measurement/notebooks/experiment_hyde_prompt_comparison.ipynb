# %% [markdown]
# ### Experiment:  Performance of HYDE prompts on context retrieval distance & response time

# %% [markdown]
# **Background:**
# HYDE (Hypothetical Document Embedding) is an approach that has been indicated to improve the relevancy and comprehensiveness of RAG context retrieval by expanding a provided query prompt into a hypothetical document that can be used for context retrieval.  Different formulations of prompts may impact LLM response time and resulting embeddings.
#
# **Test Approach**
# A sample of questions will be selected from QA corpus.  Documents will be retrieved using 2 different prompts.  REesults from prompts 1, 2, and no-prompt will be compared via cosine similarity distance.

# %%
# Common import
from deh.assessment import QASetRetriever
from deh import settings
from deh.eval import generate_experiment_dataset

import pandas as pd
import os
from pathlib import Path

# %% [markdown]
# #### Test Configuration

# %%
num_samples:int = 100
experiment_folder:str = "../../data/evaluations/hyde-prompt-experiment/"
qa_data_set_file:str = "../../data/qas/squad_qas.tsv"

# Create experiment folder:
if not os.path.exists(experiment_folder):
    Path(experiment_folder).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# #### Sample QA dataset

# %%
qa_set = QASetRetriever.get_qasets(
    file_path = qa_data_set_file,
    sample_size= num_samples
)

print(f"{len(qa_set)} questions sampled from QA corpus ({qa_data_set_file})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 qa_set = QASetRetriever.get_qasets(
#       2     file_path = qa_data_set_file,
#       3     sample_size= num_samples
#       4 )
#       6 print(f"{len(qa_set)} questions sampled from QA corpus ({qa_data_set_file})")
#
# NameError: name 'QASetRetriever' is not defined

# %% [markdown]
# #### Get Similiarity Scores based on original question

# %%
def convert(response) -> pd.DataFrame:
    """Converts retrieved JSON response to Pandas DataFrame"""
    return pd.json_normalize(
        data=response["response"], record_path="context", meta=["question", "execution_time"]
    )

def api_endpoint(**kwargs) -> str:
    """Endpoint for context retrieval (h=false).
    """
    query_params = "&".join([f"{key}={kwargs[key]}" for key in kwargs])
    return f"http://{settings.API_ANSWER_ENDPOINT}/context_retrieval?{query_params}"

# Collect response:
exp_df = generate_experiment_dataset(qa_set, convert, api_endpoint)

# Store dataframe:
exp_df.to_pickle( f"{experiment_folder}/no_hyde.pkl" )
exp_df[0:1]

# %% [markdown]
# #### Get Similiarity Scores based on HYDE question (prompt=0)

# %%
def hyde_convert(response) -> pd.DataFrame:
    """Converts retrieved JSON response to Pandas DataFrame"""
    return pd.json_normalize(
        data=response["response"],
        record_path="context",
        meta=["original_question", "question", "execution_time"],
    )

def hyde_api_endpoint(**kwargs) -> str:
    """Endpoint for context retrieval w/ hyde (h=true,p=0)."""
    query_params = "&".join([f"{key}={kwargs[key]}" for key in kwargs])
    return (
        f"http://{settings.API_ANSWER_ENDPOINT}/context_retrieval?h=True&{query_params}&p=0"
    )

# Collect response:
exp_df = generate_experiment_dataset(qa_set, hyde_convert, hyde_api_endpoint)

# Store dataframe:
exp_df.to_pickle( f"{experiment_folder}/hyde_p0_retrieval.pkl" )
exp_df[0:1]

# %% [markdown]
# #### Get Similiarity Scores based on HYDE question (prompt=1)

# %%
def hyde_convert(response) -> pd.DataFrame:
    """Converts retrieved JSON response to Pandas DataFrame"""
    return pd.json_normalize(
        data=response["response"],
        record_path="context",
        meta=["original_question", "question", "execution_time"],
    )

def hyde_api_endpoint(**kwargs) -> str:
    """Endpoint for context retrieval w/ hyde (h=true,p=0)."""
    query_params = "&".join([f"{key}={kwargs[key]}" for key in kwargs])
    return (
        f"http://{settings.API_ANSWER_ENDPOINT}/context_retrieval?h=True&{query_params}&p=1"
    )

# Collect response:
exp_df = generate_experiment_dataset(qa_set, hyde_convert, hyde_api_endpoint)

# Store dataframe:
exp_df.to_pickle( f"{experiment_folder}/hyde_p1_retrieval.pkl" )
exp_df[0:1]

# %% [markdown]
# #### Load and merge Experiment Datasets for comparison

# %%
# Load experiment results:
context_retr_df = pd.read_pickle(f"{experiment_folder}no_hyde.pkl")
hyde_retr_p0_df = pd.read_pickle(f"{experiment_folder}hyde_p0_retrieval.pkl")
hyde_retr_p1_df = pd.read_pickle(f"{experiment_folder}hyde_p1_retrieval.pkl")

# %%
# Concatenate datasets together for comparison:

context_retr_df["q_index"] = context_retr_df["question"]
context_retr_df["q_rank"] = context_retr_df.groupby(["q_index"]).cumcount()+1
context_retr_df.reset_index(drop=True)
hyde_retr_p0_df["q_index"] = hyde_retr_p0_df["original_question"]
hyde_retr_p0_df["q_rank"] = hyde_retr_p0_df.groupby(["q_index"]).cumcount()+1
hyde_retr_p0_df.reset_index(drop=True)
hyde_retr_p1_df["q_index"] = hyde_retr_p1_df["original_question"]
hyde_retr_p1_df["q_rank"] = hyde_retr_p1_df.groupby(["q_index"]).cumcount()+1
hyde_retr_p1_df.reset_index(drop=True)

combined_df = pd.merge( context_retr_df,hyde_retr_p0_df, on=["q_index", "q_rank"], suffixes=["", "_hyde_p0"])
combined_df = pd.merge( combined_df,hyde_retr_p1_df, on=["q_index", "q_rank"], suffixes=["", "_hyde_p1"])

combined_df[0:2]
# Out:
#      id                                       page_content      type  \
# 0  None  Before World War II, Fresno had many ethnic ne...  Document
# 1  None  The "West Side" of Fresno, also often called "...  Document
#
#                       metadata.source  metadata.similarity_score  \
# 0  /data/contexts/context_425.context                   0.226851
# 1  /data/contexts/context_437.context                   0.370264
#
#                                             question execution_time  \
# 0  What ethnic neighborhood in Fresno had primari...       00:00:00
# 1  What ethnic neighborhood in Fresno had primari...       00:00:00
#
#                                              q_index  q_rank id_hyde_p0  ...  \
# 0  What ethnic neighborhood in Fresno had primari...       1       None  ...
# 1  What ethnic neighborhood in Fresno had primari...       2       None  ...
#
#                                     question_hyde_p0 execution_time_hyde_p0  \
# 0  The Japantown district in Fresno was a signifi...               00:00:01
# 1  The Japantown district in Fresno was a signifi...               00:00:01
#
#   id_hyde_p1                               page_content_hyde_p1 type_hyde_p1  \
# 0       None  Before World War II, Fresno had many ethnic ne...     Document
# 1       None  The "West Side" of Fresno, also often called "...     Document
#
#               metadata.source_hyde_p1 metadata.similarity_score_hyde_p1  \
# 0  /data/contexts/context_425.context                          0.297337
# 1  /data/contexts/context_437.context                          0.498287
#
#                            original_question_hyde_p1  \
# 0  What ethnic neighborhood in Fresno had primari...
# 1  What ethnic neighborhood in Fresno had primari...
#
#                                     question_hyde_p1 execution_time_hyde_p1
# 0  The historic Japantown district in downtown Fr...               00:00:02
# 1  The historic Japantown district in downtown Fr...               00:00:02
#
# [2 rows x 25 columns]

# %%
# Compare if the hyde p0 similarity is better than p1 (lower is better):
combined_df["similarity_diff"] = combined_df["metadata.similarity_score_hyde_p0"] - combined_df["metadata.similarity_score_hyde_p1"]

# Compare if hyde p0 response time is better than p1 (lower is better):
combined_df["response_diff"] = pd.to_timedelta(combined_df["execution_time_hyde_p0"]).dt.total_seconds() - pd.to_timedelta(combined_df["execution_time_hyde_p1"]).dt.total_seconds()

combined_df[0:10]
# Out:
#      id                                       page_content      type  \
# 0  None  Before World War II, Fresno had many ethnic ne...  Document
# 1  None  The "West Side" of Fresno, also often called "...  Document
# 2  None  The 2010 United States Census reported that Fr...  Document
# 3  None  While many homes in the neighborhood date back...  Document
# 4  None  Fresno (/ˈfrɛznoʊ/ FREZ-noh), the county seat ...  Document
# 5  None  As of the census of 2000, there were 427,652 p...  Document
# 6  None  One key figure in the plans for what would com...  Document
# 7  None  Other prominent alumni include anthropologists...  Document
# 8  None  Other: Civil rights leader W. E. B. Du Bois; p...  Document
# 9  None  In business, notable alumni include Microsoft ...  Document
#
#                        metadata.source  metadata.similarity_score  \
# 0   /data/contexts/context_425.context                   0.226851
# 1   /data/contexts/context_437.context                   0.370264
# 2   /data/contexts/context_444.context                   0.432765
# 3   /data/contexts/context_439.context                   0.479242
# 4   /data/contexts/context_423.context                   0.501168
# 5   /data/contexts/context_446.context                   0.513339
# 6  /data/contexts/context_1062.context                   0.579667
# 7   /data/contexts/context_750.context                   0.682618
# 8   /data/contexts/context_650.context                   0.700925
# 9   /data/contexts/context_744.context                   0.727760
#
#                                             question execution_time  \
# 0  What ethnic neighborhood in Fresno had primari...       00:00:00
# 1  What ethnic neighborhood in Fresno had primari...       00:00:00
# 2  What ethnic neighborhood in Fresno had primari...       00:00:00
# 3  What ethnic neighborhood in Fresno had primari...       00:00:00
# 4  What ethnic neighborhood in Fresno had primari...       00:00:00
# 5  What ethnic neighborhood in Fresno had primari...       00:00:00
# 6  What was Isiah Bowman nick name, as known by t...       00:00:00
# 7  What was Isiah Bowman nick name, as known by t...       00:00:00
# 8  What was Isiah Bowman nick name, as known by t...       00:00:00
# 9  What was Isiah Bowman nick name, as known by t...       00:00:00
#
#                                              q_index  q_rank id_hyde_p0  ...  \
# 0  What ethnic neighborhood in Fresno had primari...       1       None  ...
# 1  What ethnic neighborhood in Fresno had primari...       2       None  ...
# 2  What ethnic neighborhood in Fresno had primari...       3       None  ...
# 3  What ethnic neighborhood in Fresno had primari...       4       None  ...
# 4  What ethnic neighborhood in Fresno had primari...       5       None  ...
# 5  What ethnic neighborhood in Fresno had primari...       6       None  ...
# 6  What was Isiah Bowman nick name, as known by t...       1       None  ...
# 7  What was Isiah Bowman nick name, as known by t...       2       None  ...
# 8  What was Isiah Bowman nick name, as known by t...       3       None  ...
# 9  What was Isiah Bowman nick name, as known by t...       4       None  ...
#
#   id_hyde_p1                               page_content_hyde_p1 type_hyde_p1  \
# 0       None  Before World War II, Fresno had many ethnic ne...     Document
# 1       None  The "West Side" of Fresno, also often called "...     Document
# 2       None  While many homes in the neighborhood date back...     Document
# 3       None  The 2010 United States Census reported that Fr...     Document
# 4       None  The neighborhood includes Kearney Boulevard, n...     Document
# 5       None  Between the 1880s and World War II, Downtown F...     Document
# 6       None  One key figure in the plans for what would com...     Document
# 7       None  Other prominent alumni include anthropologists...     Document
# 8       None  The Royal Geographical Society of London and o...     Document
# 9       None  Orientalism, as theorized by Edward Said, refe...     Document
#
#                metadata.source_hyde_p1 metadata.similarity_score_hyde_p1  \
# 0   /data/contexts/context_425.context                          0.297337
# 1   /data/contexts/context_437.context                          0.498287
# 2   /data/contexts/context_439.context                          0.523486
# 3   /data/contexts/context_444.context                          0.557562
# 4   /data/contexts/context_438.context                          0.590314
# 5   /data/contexts/context_429.context                          0.591934
# 6  /data/contexts/context_1062.context                          0.396352
# 7   /data/contexts/context_750.context                          0.592633
# 8  /data/contexts/context_1034.context                          0.596248
# 9  /data/contexts/context_1037.context                          0.640191
#
#                            original_question_hyde_p1  \
# 0  What ethnic neighborhood in Fresno had primari...
# 1  What ethnic neighborhood in Fresno had primari...
# 2  What ethnic neighborhood in Fresno had primari...
# 3  What ethnic neighborhood in Fresno had primari...
# 4  What ethnic neighborhood in Fresno had primari...
# 5  What ethnic neighborhood in Fresno had primari...
# 6  What was Isiah Bowman nick name, as known by t...
# 7  What was Isiah Bowman nick name, as known by t...
# 8  What was Isiah Bowman nick name, as known by t...
# 9  What was Isiah Bowman nick name, as known by t...
#
#                                     question_hyde_p1 execution_time_hyde_p1  \
# 0  The historic Japantown district in downtown Fr...               00:00:02
# 1  The historic Japantown district in downtown Fr...               00:00:02
# 2  The historic Japantown district in downtown Fr...               00:00:02
# 3  The historic Japantown district in downtown Fr...               00:00:02
# 4  The historic Japantown district in downtown Fr...               00:00:02
# 5  The historic Japantown district in downtown Fr...               00:00:02
# 6  Isaiah Bowman, a renowned American geographer ...               00:00:01
# 7  Isaiah Bowman, a renowned American geographer ...               00:00:01
# 8  Isaiah Bowman, a renowned American geographer ...               00:00:01
# 9  Isaiah Bowman, a renowned American geographer ...               00:00:01
#
#   similarity_diff response_diff
# 0       -0.028335          -1.0
# 1       -0.074506          -1.0
# 2       -0.063884          -1.0
# 3       -0.053770          -1.0
# 4       -0.060419          -1.0
# 5       -0.056100          -1.0
# 6       -0.064123           0.0
# 7       -0.056352           0.0
# 8       -0.054344           0.0
# 9       -0.057987           0.0
#
# [10 rows x 27 columns]

# %% [markdown]
# ##### Average Response Differences

# %%
combined_df["response_diff"].mean()
# Out:
# -0.04

# %%
combined_df.describe()
# Out:
#        metadata.similarity_score     q_rank  \
# count                 600.000000  600.00000
# mean                    0.502589    3.50000
# std                     0.117522    1.70925
# min                     0.226851    1.00000
# 25%                     0.421606    2.00000
# 50%                     0.501965    3.50000
# 75%                     0.581183    5.00000
# max                     0.788057    6.00000
#
#        metadata.similarity_score_hyde_p0  metadata.similarity_score_hyde_p1  \
# count                         600.000000                         600.000000
# mean                            0.460791                           0.465835
# std                             0.134380                           0.138422
# min                             0.129452                           0.110092
# 25%                             0.364758                           0.360483
# 50%                             0.457766                           0.478531
# 75%                             0.555248                           0.572856
# max                             0.801517                           0.788275
#
#        similarity_diff  response_diff
# count       600.000000     600.000000
# mean         -0.005044      -0.040000
# std           0.062293       0.615656
# min          -0.226766      -2.000000
# 25%          -0.038440       0.000000
# 50%          -0.001102       0.000000
# 75%           0.029025       0.000000
# max           0.225366       1.000000

# %%
combined_df["similarity_diff"].mean()
# Out:
# -0.0050437915234864085

# %% [markdown]
# ##### Conclusion
# p0 seems to outperform p1 on both response and similarity results.
